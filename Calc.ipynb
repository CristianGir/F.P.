# %%
con=set({'a','b','c','d','e','f','g','h','i','j','k','l','m','n','ñ','o','p','q','r','s','t','u','v','w','x','y','z','|','°','¬','!','"','#','$','%','&','/','(',')','=','?',"'","''\''",'¿','¡',',',';','.',':','-','_','{','}','[',']','^','`','<','>','@','´','¨','+','*','~'})
o=None
v=None
x=None
rcv=None
g='Escriba el número '
z='z'
y='q'
conf=None

# %%
print('Se va a realizar una operación, por favor siga las instrucciones, las opciones se mostrarán \
entre comillas "", escríbalas tal cual como se vean. \n')
conf='y'
while conf=='y':
#Introducción de tipo de datos.
        f=input('Por favor seleccione con qué tipo de números se va a trabajar: enteros "z", racionales "q": \n')
        f=f.lower()
        while(f!='z')and(f!='q'):
            f=input('Por favor elija una opción válida. enteros "z", racionales "q": ')
            f=f.lower()
        if f=='z':
            c=input('Escriba que operación desea realizar: suma "+", resta "-", multiplicación "*", división "/" o raíz "//": \n')
            c=c.lower()
            while(c!='+')and(c!='-')and(c!='*')and(c!='/')and(c!='//'):
                c=input('Por favor elija una opción válida. suma "+", resta "-", multiplicación "*", división "/" o raíz "//": \n')
#Identificación de operación.
#Suma.
            if c=='+':
                x='al que se le sumará:'
                v='que se sumará: '
                print('Se realizará una suma.')
#Resta.
            elif c=='-':
                x='al que se le restará: '
                v='que se restará: '
                print('Se realizará una resta.')
#Multiplicación.
            elif c=='*':
                x='que será multiplicado: '
                v='por el que se multiplicará: '
                print('Se realizará una multiplicación.')
#División.
            elif c=='/':
                x='que será dividido: '
                v='por el que se dividirá: '
                print('Se realizará una división.')
#Raíz.
            elif c=='//':
                x='al que se le calculará la raíz: '
                v='que será la potencia de la raíz: '
                print('Se realizará una raíz.')
#Entrada de datos numéricos.
            p=input(g+x)
            while p in con:
                p=input('Por favor ingrese un NÚMERO: ')
            pf=p.find('.')
            if pf==-1:
                ver='t'
            else:
                ver='f'
            while ver=='f' or p in con:
                p=(input('Por favor ingrese un número ENTERO: '))
                pf=p.find('.')
                if pf==-1:
                    ver='t'
                else:
                    ver='f'
                    
            if ver=='t':
#Separación entre p y b.
                b=input(g+v)
                while (c=='/' or c=='//'):
                    b=input('No es posible dividir por cero, por favor escoja otro número: ')
                while b in con:
                    b=input('Por favor ingrese un NÚMERO: ')
                bf=b.find('.')
                if bf==-1:
                    ver='t'
                else:
                    ver='f'
                while (ver=='f' or b in con):
                    b=input('Por favor ingrese un número ENTERO: ')
                    bf=b.find('.')
                    if bf==-1:
                        ver='t'
                    else:
                        ver='f'
                    while (c=='/' or c=='//') and b=='0':
                        b=input('No es posible dividir por cero, por favor escoja otro número: ')
            
            p=int(p)
            b=int(b)
#Asignación de operaciones.
#Suma.
            if c=='+':
                o=p+b    
#Resta.
            elif c=='-':
                o=p-b
#Multiplicación.
            elif c=='*':
                o=p*b
#División.
            elif c=='/':
                while b==0 or b in con:
                    b=input('Esta operación no es posible, por favor elija otro número: ')
                    bfd=b.find('.')
                if bfd==-1:
                    ver='t'
                else:
                    ver='f'
                    while ver=='f' or b in :con
                        b=input('Por favor ingrese un número ENTERO: ')
                        bfd=b.find('.')
                        if bfd==-1:
                            ver='t'
                        else:
                            ver='f'
                        b=int(b)
                o=p/b
#Raiz.
            elif c=='//':
                while (b==0)or(b in con):
                    b=input('Esta operación no es posible, por favor elija otro número: ')
                    bfd=b.find('.')
                if bfd==-1:
                    ver='t'
                else:
                    ver='f'
                    while ver=='f' or b in con:
                        b=input('Por favor ingrese un número ENTERO: ')
                        bfd=b.find('.')
                        if bfd==-1:
                            ver='t'
                        else:
                            ver='f'
                b=int(b)
            o=(p**(1/b))
#Entrega de resultado.
            print('\nEl resultado de la operación es: ',round(o,3))
            
#División entre enteros y racionales.

        elif f=='q':
            con.discard('.')
            print('Para escribir números decimales, deben ser separados por puntos.')
            c=input('Escriba que operación desea realizar: suma"+", resta"-", multiplicación"*", división"/" o raíz "//": \n')
            while (c!='+')and(c!='-')and(c!='*')and(c!='/')and(c!='//'):
                c=input('Por favor elija una opción válida. suma "+", resta "-", multiplicación "*", división "/" o raíz  "//": \n')
#Identificación de operación.
#Suma.
            if c=='+':
                x='al que se le sumará: '
                v='que se sumará: '
                print('Se realizará una suma.')
#Resta.
            elif c=='-':
                x='al que se le restará: '
                v='que se restará: '
                print('Se realizará una resta.')
#Multiplicación.
            elif c=='*':
                x='que será multiplicado: '
                v='por el que se multiplicará: '
                print('Se realizará una multiplicación.')
#División.
            elif c=='/':
                x='que será dividido: '
                v='por el que se dividirá: '
                print('Se realizará una división.')
#Raíz.
            elif c=='//':
                x='al que se le calculará la raíz: '
                v='que será la potencia de la raíz: '
                print('Se realizará una raíz.')
            else:
                print('Por favor seleccione una opción correcta')
#Entrada de datos numéricos.
            p=input(g+x)
            while p in con:
                p=(input('Por favor ingrese un NÚMERO: '))
#Separación entre p y b.
            b=input(g+v)
            while (c=='/' or c=='//') and b=='0':
                b=input('No es posible dividir entre cero, por favor escoja otro número: ')
            while b in con:
                b=(input('Por favor ingrese un NÚMERO: '))
                while (c=='/' or c=='//') and b=='0' or b in con:
                    b=input('No es posible dividir entre cero, por favor escoja otro número: ')
            p=float(p)
            b=float(b)
#Asignación de operaciones.
#Suma.
            if c=='+':
                o=p+b
#Resta.
            elif c=='-':
                o=p-b
#Multiplicación.
            elif c=='*':
                o=p*b
#División.
            elif c=='/':
                while (b==0)or(b in con):
                    b=input('Esta operación no es posible, por favor elija otro número: ')
                b=float(b)
                o=p/b
#Raíz.
            elif c=='//':
                while (b==0)or(b in con):
                    b=input('Esta operación no es posible, por favor elija otro número: ')
                b=float(b)
                o=(p**(1/b))
#Entrega de resultado.
            print('\nEl resultado de la operación es: ',round(o,3))
            print('====================================')
#Reiniciar aplicación.
        conf=input('¿Desea realizar otra operación? y/n: ')
        conf=conf.lower()
        while (conf!='y')and(conf!='n'):
            conf=input('Por favor selecciona una opción válida. ¿Desea realizar otra operación? y/n: ')
        print('====================================\n')
# Out:
# Se va a realizar una operación, por favor siga las instrucciones, las opciones se mostrarán entre comillas "", escríbalas tal cual como se vean.
