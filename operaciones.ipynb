# %% [markdown]
# # Operaciones matemáticas.

# %%
#Suma
15+6
# Out:
# 21

# %%
#Resta
30-12
# Out:
# 18

# %%
#Multiplicación
15*40
# Out:
# 600

# %%
#División
1500//15
# Out:
# 100

# %%
#Módiulo
7%2
# Out:
# 1
